# %%
#csv good for storing tabular data
#import csv

#with open("data.csv", "r") as csvfile:
# #reader.csv

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %%
#read CSV file

#Pandas
#Numpy 

#we use pip to install them
#we can install from the cells
#e.g %pip install pandas
#pandas has modules for data science
#numpy has numerical values  


import pandas as pd
#reading a CSV file
import numpy as np

#df is data frame
df = pd.read_csv('data.csv')

#display basic infor
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
import matplotlib as mpl
print(mpl.__version__)
# Out:
# 3.9.2

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data.csv')

# %%
#check empty cells
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
#check wrong formats
print(df.dtypes)

#or use for loop
for col in ['Duration', 'Pulse', 'Maxpulse', 'Calories']:
    if not pd.to_numeric(df[col], errors= 'coerce').notnull()

# %%
for col in ['Duration', 'Pulse', 'Maxpulse', 'Calories']:
    if (df[col] < 0).any():
        print(f"Negative values found in columns: {col}")

# %%
df.duplicated()
if duplicates.any():
    print("Duplicates found")
else:
    print("Duplicates not found")

# %%
"""
recommendations 
1. Handle empty cells(donot remove them)
2. convert wrong formats
3. correct wroong data
4. remove duplicates
"""

# %%
for col in ['Duration', 'Pulse', 'Maxpulse', 'Calories']:
    df[col].fillna(df[col].mean(), inplace = True)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# C:\Users\user\AppData\Local\Temp\ipykernel_8108\3214077311.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print(df.head(30))
# Out:
#     Duration  Pulse  Maxpulse    Calories
# 0         60    110       130  409.100000
# 1         60    117       145  479.000000
# 2         60    103       135  340.000000
# 3         45    109       175  282.400000
# 4         45    117       148  406.000000
# 5         60    102       127  300.000000
# 6         60    110       136  374.000000
# 7         45    104       134  253.300000
# 8         30    109       133  195.100000
# 9         60     98       124  269.000000
# 10        60    103       147  329.300000
# 11        60    100       120  250.700000
# 12        60    106       128  345.300000
# 13        60    104       132  379.300000
# 14        60     98       123  275.000000
# 15        60     98       120  215.200000
# 16        60    100       120  300.000000
# 17        45     90       112  375.790244
# 18        60    103       123  323.000000
# 19        45     97       125  243.000000
# 20        60    108       131  364.200000
# ...

# %%
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#EDA
#check the shape of the dataset
print("Shape of the dataset: ", df.shape)
# Out:
# Shape of the dataset:  (169, 4)

# %%
print("Summary of the statstics")
print(df.describe())
# Out:
# Summary of the statstics
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   169.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   262.385991
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   253.300000
# 50%     60.000000  105.000000  131.000000   321.000000
# 75%     60.000000  111.000000  141.000000   384.000000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setting uup the figure size
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(df['Duration'], bins=30, kde = True)
plt.title('Duration Distribution')

#plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 2)
sns.histplot(df['Pulse'], bins=30, kde = True)
plt.title('Pulse Distribution')
# Out:
# Text(0.5, 1.0, 'Pulse Distribution')

# %%
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 3)
sns.histplot(df['Maxpulse'], bins=30, kde = True)
plt.title('Maxpulse Distribution')

plt.subplot(2, 2, 4)
sns.histplot(df['Calories'], bins=30, kde = True)
plt.title('Calories Distribution')
# Out:
# Text(0.5, 1.0, 'Calories Distribution')

# %%
#scatter plot of Duration vs Pulse
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.scatterplot(x='Duration', y='Pulse', data=df)
plt.title('Duration vs Pulse')

plt.subplot(2, 2, 2)
sns.scatterplot(x='Maxpulse', y='Calories', data=df)
plt.title('Maxpluse vs Calories')
# Out:
# Text(0.5, 1.0, 'Maxpluse vs Calories')

# %%
#Correlation
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
